# %% [markdown]
# <a href="https://colab.research.google.com/github/Geriys/VKirillV/blob/main/HW_2_sql_GOOD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect(':memory:')

# %% [markdown]
# https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html

# %%
data = pd.read_csv('boston.csv')
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.to_sql('boston', con, index=False, if_exists='replace')
# Out:
# 506

# %%
pd.read_sql(
    '''
    SELECT * FROM boston
    limit 5
    ''',
    con,
)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
tasks = 0

# %% [markdown]
# ### Все задания нужно выполнить только с помощью sql

# %% [markdown]
# 1. Выведите количество пустых значений по колонкам CRIM, ZN, INDUS, CHAS, NOX (название колонки, кол-во пустых значений)

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT (SELECT COUNT(CRIM) FROM boston WHERE CRIM == 0.0) as CRIM,
           (SELECT COUNT(ZN) FROM boston WHERE ZN == 0.0) as ZN,
           (SELECT COUNT(INDUS) FROM boston WHERE INDUS == 0.0) as INDUS,
           (SELECT COUNT(CHAS) FROM boston WHERE  CHAS == 0.0) as CHAS,
           (SELECT COUNT(NOX) FROM boston WHERE NOX == 0.0) as NOX
    ---FROM boston
    ---limit 1
    ''',
    con,
)
# Out:
#    CRIM   ZN  INDUS  CHAS  NOX
# 0     0  372      0   471    0

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT "CRIM_zeroes" AS name, COUNT(CRIM) AS count FROM (SELECT * FROM boston WHERE CRIM = 0)
    UNION
    SELECT "ZN_zeroes" AS name, COUNT(ZN) AS count FROM (SELECT * FROM boston WHERE ZN = 0)
    UNION
    SELECT "INDUS_zeroes" AS name, COUNT(INDUS) AS count FROM (SELECT * FROM boston WHERE INDUS = 0)
    UNION
    SELECT "CHAS_zeroes" AS name, COUNT(CHAS) AS count FROM (SELECT * FROM boston WHERE CHAS = 0)
    UNION
    SELECT "NOX_zeroes" AS name, COUNT(NOX) AS count FROM (SELECT * FROM boston WHERE NOX = 0)
    ''',
    con,
)
# Out:
#            name  count
# 0   CHAS_zeroes    471
# 1   CRIM_zeroes      0
# 2  INDUS_zeroes      0
# 3    NOX_zeroes      0
# 4     ZN_zeroes    372

# %% [markdown]
# 2. Выведите количество уникальных значений по колонокам CRIM, ZN, INDUS, CHAS, NOX (название колонки, кол-во уникальных значений)

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT (SELECT COUNT(DISTINCT CRIM) FROM boston) as CRIM,
           (SELECT COUNT(DISTINCT ZN) FROM boston) as ZN,
           (SELECT COUNT(DISTINCT INDUS) FROM boston) as INDUS,
           (SELECT COUNT(DISTINCT CHAS) FROM boston) as CHAS,
           (SELECT COUNT(DISTINCT NOX) FROM boston) as NOX
    ---FROM boston
    ---limit 1
    ''',
    con,
)
# Out:
#    CRIM  ZN  INDUS  CHAS  NOX
# 0   504  26     76     2   81

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT "CRIM_uniq" AS name, COUNT(CRIM) AS count FROM (SELECT DISTINCT CRIM FROM boston)
    UNION
    SELECT "ZN_uniq" AS name, COUNT(ZN) AS count FROM (SELECT DISTINCT ZN FROM boston)
    UNION
    SELECT "INDUS_uniq" AS name, COUNT(INDUS) AS count FROM (SELECT DISTINCT INDUS FROM boston)
    UNION
    SELECT "CHAS_uniq" AS name, COUNT(CHAS) AS count FROM (SELECT DISTINCT CHAS FROM boston)
    UNION
    SELECT "NOX_uniq" AS name, COUNT(NOX) AS count FROM (SELECT DISTINCT NOX FROM boston)
    ''',
    con,
)
# Out:
#          name  count
# 0   CHAS_uniq      2
# 1   CRIM_uniq    504
# 2  INDUS_uniq     76
# 3    NOX_uniq     81
# 4     ZN_uniq     26

# %% [markdown]
# 3. Выведите колонки, у которых медиана равна минимальному значению (название колонки) выбирая из CRIM, ZN, INDUS, CHAS, NOX.
# Напишите какой вывод можно сделать по данным в этих колонках

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT *
    FROM
    (
    SELECT 'CRIM' AS name, (SELECT MIN(CRIM) FROM boston) AS min,
    (SELECT AVG(CRIM) FROM (SELECT CRIM FROM boston ORDER BY CRIM
    LIMIT 2 - (SELECT COUNT(*) FROM boston) % 2    -- odd 1, even 2
    OFFSET (SELECT (COUNT(*) - 1) / 2 FROM boston))) AS median

    UNION
    SELECT 'ZN' AS name, (SELECT MIN(ZN) FROM boston) AS min,
    (SELECT AVG(ZN) FROM (SELECT ZN FROM boston ORDER BY ZN
    LIMIT 2 - (SELECT COUNT(*) FROM boston) % 2    -- odd 1, even 2
    OFFSET (SELECT (COUNT(*) - 1) / 2 FROM boston))) AS median

    UNION
    SELECT 'INDUS' AS name, (SELECT MIN(INDUS) FROM boston) AS min,
    (SELECT AVG(INDUS) FROM (SELECT INDUS FROM boston ORDER BY INDUS
    LIMIT 2 - (SELECT COUNT(*) FROM boston) % 2    -- odd 1, even 2
    OFFSET (SELECT (COUNT(*) - 1) / 2 FROM boston))) AS median

    UNION
    SELECT 'CHAS' AS name, (SELECT MIN(CHAS) FROM boston) AS min,
    (SELECT AVG(CHAS) FROM (SELECT CHAS FROM boston ORDER BY CHAS
    LIMIT 2 - (SELECT COUNT(*) FROM boston) % 2    -- odd 1, even 2
    OFFSET (SELECT (COUNT(*) - 1) / 2 FROM boston))) AS median

    UNION
    SELECT 'NOX' AS name, (SELECT MIN(NOX) FROM boston) AS min,
    (SELECT AVG(NOX) FROM (SELECT NOX FROM boston ORDER BY NOX
    LIMIT 2 - (SELECT COUNT(*) FROM boston) % 2    -- odd 1, even 2
    OFFSET (SELECT (COUNT(*) - 1) / 2 FROM boston))) AS median

    )
    WHERE (min - median) = 0
   ''',
  con,
)
# Out:
#    name  min  median
# 0  CHAS  0.0     0.0
# 1    ZN  0.0     0.0

# %%
#Вывод:
#В столбцах CHAS и ZN больше всего нулевых значений, поэтому их медиана также ровна нулю, как и минимальное значение.
#То, что значение медианы CHAS равно нулю означает еще и то, что больше половины домов расположено далеко от рек.

# %% [markdown]
# 4. Выведите разницу между среднем количеством комнат(RM) в домах с самой дорогой стоимостью(MEDV) и 25 самыми дешевыми домами.
# Аналогично по 50, 100, 200, 300 самыми дешевыми домами. (кол-во домов(25,50,100,200,300), среднее кол-во комнат в них, среднее кол-во комнат в самых дорогих, разница).
# Напишите влияет ли кол-во комнат на стоимость и как сильно.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT *,
    (avg_RM_by_max_MEDV - avg_RM_by_cheapest_homes) AS diff
    FROM(

    SELECT 25 AS cheapest_homes_count,
    (SELECT AVG(RM) FROM (SELECT * FROM boston ORDER BY MEDV LIMIT 25)) AS avg_RM_by_cheapest_homes,
    (SELECT AVG(RM) FROM boston WHERE MEDV = (SELECT MAX(MEDV) FROM boston)) AS avg_RM_by_max_MEDV

    UNION
    SELECT 50 AS cheapest_homes_count,
    (SELECT AVG(RM) FROM (SELECT * FROM boston ORDER BY MEDV LIMIT 50)) AS avg_RM_by_cheapest_homes,
    (SELECT AVG(RM) FROM boston WHERE MEDV = (SELECT MAX(MEDV) FROM boston)) AS avg_RM_by_max_MEDV

    UNION
    SELECT 100 AS cheapest_homes_count,
    (SELECT AVG(RM) FROM (SELECT * FROM boston ORDER BY MEDV LIMIT 100)) AS avg_RM_by_cheapest_homes,
    (SELECT AVG(RM) FROM boston WHERE MEDV = (SELECT MAX(MEDV) FROM boston)) AS avg_RM_by_max_MEDV

    UNION
    SELECT 200 AS cheapest_homes_count,
    (SELECT AVG(RM) FROM (SELECT * FROM boston ORDER BY MEDV LIMIT 200)) AS avg_RM_by_cheapest_homes,
    (SELECT AVG(RM) FROM boston WHERE MEDV = (SELECT MAX(MEDV) FROM boston)) AS avg_RM_by_max_MEDV

    UNION
    SELECT 300 AS cheapest_homes_count,
    (SELECT AVG(RM) FROM (SELECT * FROM boston ORDER BY MEDV LIMIT 300)) AS avg_RM_by_cheapest_homes,
    (SELECT AVG(RM) FROM boston WHERE MEDV = (SELECT MAX(MEDV) FROM boston)) AS avg_RM_by_max_MEDV

    )
    ''',
    con,
)
# Out:
#    cheapest_homes_count  avg_RM_by_cheapest_homes  avg_RM_by_max_MEDV  \
# 0                    25                  5.747840               7.484
# 1                    50                  5.753240               7.484
# 2                   100                  5.887120               7.484
# 3                   200                  5.911705               7.484
# 4                   300                  5.972227               7.484
#
#        diff
# 0  1.736160
# 1  1.730760
# 2  1.596880
# 3  1.572295
# 4  1.511773

# %%
#Выводы:
#Количество комнат, особенно с увеличением выборки (соответсвенно и с ее усреднением) не влияет на стоимость домов. Вероятно, на это влияют другие параметры, например, расположение дома.

# %% [markdown]
# 5. Выведите ранги значений колонки LSTAT(процент населения с более низким статусом) в домах с самой дорогой стоимостью (значение LSTAT, стоимость, ранг) среди всех значений LSTAT. Напишите какой вывод можно сделать по этим данным.

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT *
    FROM(SELECT LSTAT, MEDV, (RANK() OVER(ORDER BY LSTAT)) as RANG FROM boston)
    WHERE MEDV = (SELECT MAX(MEDV) FROM boston)
    ''',
    con,
)
# Out:
#     LSTAT  MEDV  RANG
# 0    1.73  50.0     1
# 1    1.92  50.0     2
# 2    2.88  50.0     6
# 3    2.96  50.0     8
# 4    2.97  50.0     9
# 5    3.16  50.0    15
# 6    3.26  50.0    17
# 7    3.32  50.0    18
# 8    3.70  50.0    26
# 9    3.73  50.0    27
# 10   4.45  50.0    41
# 11   4.63  50.0    50
# 12   5.12  50.0    67
# 13   7.44  50.0   141
# 14   8.88  50.0   181
# 15   9.53  50.0   203

# %%
#Можно сделать выводы о том, что в домах с более высокой стоимостью будет более низкий процент населения с низким статусом.
#Максимальное место по самому низкому статусу в доме с максимальной стоимостью занимает 203 место из 506.
#Т. е. самый менее статусный по населению дом из выборки занимает середину из всех домов. При этом 14 домов из выбранных 16 занимают позиции в топ 100.

# %% [markdown]
# 6. Выведите среднюю стоимость домов граничащих с рекой(CHAS) и нет (граничит/не граничит, стоимость)

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT

    CASE
    WHEN CHAS = 0 THEN 'Не граничит'
    WHEN CHAS = 1 THEN 'Граничит'

    END as 'Граничит с рекой',
    AVG(MEDV) as 'Средняя стоимость дома'

    FROM boston
    GROUP BY CHAS
    ''',
    con,
)
# Out:
#   Граничит с рекой  Средняя стоимость дома
# 0      Не граничит               22.093843
# 1         Граничит               28.440000

# %% [markdown]
# 7. Выведите все колонки, у которых среднее значение выше, когда дом граничит с рекой (название колонки) выбирая из CRIM, ZN, INDUS, CHAS, NOX. Напишите какой вывод можно сделать по этим данным.

# %%
#Вывод всех данных
tasks+=1
pd.read_sql(
    '''
    SELECT AVG(CHAS) as GRANICH, AVG(CRIM), AVG(ZN), AVG(INDUS), AVG(NOX)
    FROM boston
    GROUP BY CHAS
    ''',
    con,
)
# Out:
#    GRANICH  AVG(CRIM)    AVG(ZN)  AVG(INDUS)  AVG(NOX)
# 0      0.0   3.723215  11.634820   11.019193  0.551817
# 1      1.0   1.851670   7.714286   12.719143  0.593426

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT *
    FROM
    (
    SELECT 'CRIM' AS name, (SELECT AVG(CRIM) FROM (SELECT CRIM FROM boston WHERE CHAS = 0)) AS AVG_far_river,
    (SELECT AVG(CRIM) FROM (SELECT CRIM FROM boston WHERE CHAS = 1)) AS AVG_nearby_river

    UNION
    SELECT 'ZN' AS name, (SELECT AVG(ZN) FROM (SELECT ZN FROM boston WHERE CHAS = 0)) AS AVG_far_river,
    (SELECT AVG(ZN) FROM (SELECT ZN FROM boston WHERE CHAS = 1)) AS AVG_nearby_river

    UNION
    SELECT 'INDUS' AS name, (SELECT AVG(INDUS) FROM (SELECT INDUS FROM boston WHERE CHAS = 0)) AS AVG_far_river,
    (SELECT AVG(INDUS) FROM (SELECT INDUS FROM boston WHERE CHAS = 1)) AS AVG_nearby_river

    UNION
    SELECT 'NOX' AS name, (SELECT AVG(NOX) FROM (SELECT NOX FROM boston WHERE CHAS = 0)) AS AVG_far_river,
    (SELECT AVG(NOX) FROM (SELECT NOX FROM boston WHERE CHAS = 1)) AS AVG_nearby_river

    )
    WHERE AVG_far_river < AVG_nearby_river
    ''',
    con,
)
# Out:
#     name  AVG_far_river  AVG_nearby_river
# 0  INDUS      11.019193         12.719143
# 1    NOX       0.551817          0.593426

# %%
#Возли рек могут распологаться производства использующие воду из них. Они и повышают концентрацию оксида азота в воздухе.

# %% [markdown]
# 8. Выведите значения долей промышленной застройки(INDUS), концентрации оксидов азота(NOX) и по их перцентилям - 10, 20 ... 100 ( перцетиль(10,20...100),значение INDUS, значение NOX). Напишите прослеживается между ними взаимосвязь

# %%
tasks+=1
pd.read_sql(
    '''
    SELECT *
    FROM
    (
       SELECT 10 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 1/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 1/10 -1) AS NOX_percentile

       UNION
       SELECT 20 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 2/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 2/10 -1) AS NOX_percentile

       UNION
       SELECT 30 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 3/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 3/10 -1) AS NOX_percentile

       UNION
       SELECT 40 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 4/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 4/10 -1) AS NOX_percentile

       UNION
       SELECT 50 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 5/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 5/10 -1) AS NOX_percentile

       UNION
       SELECT 60 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 6/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 6/10 -1) AS NOX_percentile

       UNION
       SELECT 70 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 7/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 7/10 -1) AS NOX_percentile

       UNION
       SELECT 80 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 8/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 8/10 -1) AS NOX_percentile

       UNION
       SELECT 90 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 9/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 9/10 -1) AS NOX_percentile

       UNION
       SELECT 100 AS percentile,
       (SELECT INDUS FROM boston ORDER BY INDUS LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 10/10 -1) AS INDUS_percentile,
       (SELECT NOX FROM boston ORDER BY NOX LIMIT 1
       OFFSET (SELECT COUNT(*) FROM boston) * 10/10 -1) AS NOX_percentile

    )

    ''',
    con,
)
# Out:
#    percentile  INDUS_percentile  NOX_percentile
# 0          10              2.89           0.426
# 1          20              4.15           0.442
# 2          30              5.86           0.469
# 3          40              7.07           0.507
# 4          50              9.69           0.538
# 5          60             12.83           0.575
# 6          70             18.10           0.605
# 7          80             18.10           0.668
# 8          90             19.58           0.713
# 9         100             27.74           0.871

# %%
#Выводы
#С повышением доли неторгового бизнеса растёт и содержание оксидов азота в воздухе.
#Из этого можно сделать вывод, что неторговый бизнес - это производства, которые своими выбросами повышают содержание оскидов азота.

# %% [raw]
# CRIM - уровень преступности на душу населения
# ZN - доля земель под жилую застройку зонирована под участки площадью более 25 000 кв. футов.
# INDUS - доля акров неторгового бизнеса на город.
# CHAS - 1, если граничит с рекой, 0 иначе
# NOX - концентрация оксидов азота (частей на 10 миллионов)
# RM - среднее количество комнат в квартире
# AGE - доля жилых домов, построенных до 1940 г.
# DIS - взвешенные расстояния до пяти центров занятости Бостона
# RAD - индекс доступности к радиальным магистралям
# TAX - полная ставка налога на имущество за 10 000 долларов США
# PTRATIO - соотношение учеников и учителей по городам
# B - 1000(Bk - 0.63)^2, где Bk доля чернокожих людей по городам
# LSTAT - % более низкого статуса населения
# MEDV - Средняя стоимость домов в 1000 долларов.

# %%
if tasks==8:
    print('Выполнены все задания 🙂')
else:
    print('Выполнены не все задания! 🙀')
